# %% [markdown]
# <center><img src="https://i.pinimg.com/webp/1200x/47/6f/07/476f07bee96bdbc9b0c97acbc01175d3.webp" width="1200" height="300"></center>
#
# ## <b>1 <span style='color:#F1A424'>|</span> 오늘 공부할 주제</b>
#
# <div style="color:white;display:fill;border-radius:8px;font-size:100%; letter-spacing:1.0px;"><p style="padding: 5px;color:white;text-align:left;"><b><span style='color:#F1A424'>WHAT WE WILL DO IN THIS SECTION</span></b></p></div>
#
# - 날짜 : 2026-06-09(화요일)
# - 핵심 내용 :
# - 키워드 :
# - 사용할 하이라이트 : **<mark style="background-color:#fffbc9;color:black;border-
# radius:5px;opacity:1.0"> Subword 방식의 tokenizers  library</mark>**
#
# <br>
#
# <div style="color:white;display:fill;border-radius:8px;background-color:#323232;font-size:150%; letter-spacing:1.0px"><p style="padding: 12px;color:white;"><b><b><span style='color:white'><span style='color:#F1A424'>1.1 | </span></span></b> 소주제 시작</b></p></div>
#
# - 내용 정리

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#323232;font-size:150%; letter-spacing:1.0px"><p style="padding: 12px;color:white;"><b><b><span style='color:white'><span style='color:#F1A424'>1.2 |
# </span></span></b> 소주제 2</b></p></div>
#
# - 내용 정리

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#323232;font-size:150%; letter-spacing:1.0px"><p style="padding: 12px;color:white;"><b><b><span style='color:white'><span style='color:#F1A424'>1.3 | </span></span></b> Word 소주제3</b></p></div>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#323232;font-size:150%; letter-spacing:1.0px"><p style="padding: 12px;color:white;"><b><b><span style='color:white'><span style='color:#F1A424'>1.4 | </span></span></b>소주제 4</b></p></div>

# %% [markdown]
# ### <b><span style='color:#F1A424'>혹시나 추가적으로 배우는 개념이 있다면 </span></b>
#
# - 요런 식으로 정리해보세요

# %% [markdown]
# **<mark style="background-color: #ffdf3d;color:black;border-radius:5px;opacity:1.0">🤔나름대로 해석하기 </mark>**
# 1. 국민청원이라는 한정적인 데이터셋 ➔ 스포츠 데이터에 대한 도메인이 맞지 않음.<br> 범용적으로 쓰기 위해서는 다양한 주제에 대한 학습data가 필요함
# 2. 기본 토큰이 8000개가 넘음, 근데 우리는 10000개로 한정 <br>➔ 실제 청원데이터로 만들어진 건 2000여건 정도 뿐. max_token의 한정 <br>
# ➔ vocab 사이즈를 키워야하지 않을까?

# %% [markdown]
# **<mark style="background-color: #a5f7cd;color: #161616; padding: 4px;border-radius:5px;opacity:1.0">⭐이게 중요띠?</mark>**
# - 알아두거나 메모하고 싶은거
